# %% [markdown]
# # 1 Exploratory Analysis: Pokemon (5 points)

# %%
import pandas as pd

pokemon_link = 'https://raw.githubusercontent.com/CUNY-CISC-3225/datasets/refs/heads/main/pokemon.csv'
pokemon_df = pd.read_csv(pokemon_link)
pokemon_df.head(10)
# Out:
#    attack  base_happiness  cap_rate  defense  exp_growth  height  hp  \
# 0      49              70        45       49     1059860     0.7  45
# 1      62              70        45       63     1059860     1.0  60
# 2     100              70        45      123     1059860     2.0  80
# 3      52              70        45       43     1059860     0.6  39
# 4      64              70        45       58     1059860     1.1  58
# 5     104              70        45       78     1059860     1.7  78
# 6      48              70        45       65     1059860     0.5  44
# 7      63              70        45       80     1059860     1.0  59
# 8     103              70        45      120     1059860     1.6  79
# 9      30              70       255       35     1000000     0.3  45
#
#          name  pokedex_number  speed type_1  type_2  weight  generation  \
# 0   Bulbasaur               1     45  grass  poison     6.9           1
# ...

# %% [markdown]
# # 2 Grouping (2 points)

# %% [markdown]
# # 3 Hierarchical Indexing (3 points)
